# %%
import pandas as pd

# %%
#There are 2 objects in Pandas - DataFrame and Series
#DataFrame - it is a table. contains an array of individual entries. 

#Syntax of generating a new one is a dictionary whoes keys are the column names and values are list of entries.

pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob':['Yo soy alto', 'Mi ojos negros'], 'Sue': ['Yo soy bonita', 'Mi padre es un mecanico']})
# Out:
#               Bob                      Sue
# 0     Yo soy alto            Yo soy bonita
# 1  Mi ojos negros  Mi padre es un mecanico

# %%
#By default the above consttuctor uses ascending count (0,1,2..) for row lables.
#The list of row labels used in a DF is known as an Index.

pd.DataFrame({'Bob':['Yo soy alto', 'Mi ojos negros'], 
              'Sue': ['Yo soy bonita', 'Mi padre es un mecanico']},
            index=['Product A', 'Product B'])
# Out:
#                       Bob                      Sue
# Product A     Yo soy alto            Yo soy bonita
# Product B  Mi ojos negros  Mi padre es un mecanico

# %%
#Series is a sequence of data values. A DF is a table and a series is a list.

pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#A series is a single column of DF. 
#We can assign column values to the Series the same way as above (using index)
#Series does not have a column name. It has one overall name.

pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name = 'Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
#DF is actually a bunch of series glued together.

# %%
##################       NOT WORKING      ######################

#Download the wine review data set from kaggle

import os
import urllib

DOWNLOAD_ROOT = "https://www.kaggle.com/zynicide/wine-reviews/winemag-data-130k-v2.csv"
DATASET_PATH = os.path.join("datasets","")
FILENAME = "winemag-data-130k-v2.csv"

def fetch_data(dataset_path = DATASET_PATH, download_root=DOWNLOAD_ROOT, filename=FILENAME):
    if not os.path.isdir(dataset_path):
        os.makedirs(dataset_path)
    print("Downloading", filename)
    data_path = os.path.join(dataset_path, filename)
    urllib.request.urlretrieve(download_root, data_path)
    print("Downloaded", filename, "stored in path", dataset_path)
    
#fetch_data()

# %%
#Read the downloaded csv file
#If the csv file has a built in index column 
#   then we need to specify in the read_csv function to read that column as index 
#   instead of creating a new index column.

DATASET_PATH = os.path.join("datasets","")
FILENAME = "winemag-data-130k-v2.csv"

def load_wine_data(dataset_path = DATASET_PATH, filename = FILENAME):
    csv_path = os.path.join(dataset_path, filename)
    return pd.read_csv(csv_path, index_col=0)

wine_reviews = load_wine_data()

# %%
wine_reviews.shape  #Helps to see how large the DF is.
# Out:
# (129971, 13)

# %%
wine_reviews.head()   #Gives the top 5 rows in the DF
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
#Accessing the property of a DF
wine_reviews.country.value_counts()
#OR
wine_reviews['country'].value_counts()  #[] can handle column name with reserved characters.
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %%
wine_reviews['country'][0]
# Out:
# 'Italy'

# %%
#Accessor properties of Pandas are - loc and iloc

#INDEX-BASED SELECTION (iloc)
#selects data based on its numerical position in the data.

# %%
#Eg - to select first row in the DF i.e.. select all the columns of 0th row
wine_reviews.iloc[0]
# Out:
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# ...

# %%
#Both loc and iloc are row-first and column-second. 
#This is opposite of what is done in native python (column-first, row-second)

#To get column with iloc i.e.. all the rows of the 0th column
wine_reviews.iloc[:, 0]
# Out:
# 0               Italy
# 1            Portugal
# 2                  US
# 3                  US
# 4                  US
# 5               Spain
# 6               Italy
# 7              France
# 8             Germany
# 9              France
# 10                 US
# 11             France
# 12                 US
# 13              Italy
# 14                 US
# 15            Germany
# 16          Argentina
# 17          Argentina
# 18              Spain
# 19                 US
# 20                 US
# 21                 US
# 22              Italy
# 23                 US
# 24              Italy
# 25                 US
# 26              Italy
# 27              Italy
# 28              Italy
# 29                 US
#              ...
# 129941             US
# 129942             US
# 129943          Italy
# 129944         Israel
# 129945             US
# 129946        Germany
# 129947          Italy
# 129948      Argentina
# 129949             US
# 129950             US
# ...

# %%
#Select country column from just 2nd and 3rd row
wine_reviews.iloc[1:3, 0]
# Out:
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
#We can also pass a list
wine_reviews.iloc[[0,1,2], 0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
#negative numbers can also be used in iloc  
#This will start counting forwards from the end of the values

wine_reviews.iloc[-5:] #Last 5 rows
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %%
#LABRL-BASED SELECTION (loc)
#Its the data index value here and not position that matters.

#To get the first entry in reviews
wine_reviews.loc[0,'country']
# Out:
# 'Italy'

# %%
#Get all the rows of some selected columns : done easily using loc()

wine_reviews.loc[:, ['taster_name', 'taster_teitter_handle', 'points']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                taster_name  taster_teitter_handle  points
# 0            Kerin O’Keefe                    NaN      87
# 1               Roger Voss                    NaN      87
# 2             Paul Gregutt                    NaN      87
# 3       Alexander Peartree                    NaN      87
# 4             Paul Gregutt                    NaN      87
# 5        Michael Schachner                    NaN      87
# 6            Kerin O’Keefe                    NaN      87
# 7               Roger Voss                    NaN      87
# 8       Anna Lee C. Iijima                    NaN      87
# ...

# %%
#Choosing between loc and iloc

#iloc uses Python stdlib indexing scheme, where the first element of the range is included and last one is excluded.
#So 0:10 selects 0,...,9

#loc, indexes inclusively.
#So 0:10 selects 0,...,10
#loc can index any stdlib type: strings

# %%
#Label-based selection derives its power from labels in the index. 
#Indexes are mutable. set_index() method can do this job.

wine_reviews.set_index("title")
# Out:
#                                                         country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                         Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)          Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)                US
# St. Julian 2013 Reserve Late Harvest Riesling (...           US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...           US
# Tandem 2011 Ars In Vitro Tempranillo-Merlot (Na...        Spain
# Terre di Giurfo 2013 Belsito Frappato (Vittoria)          Italy
# Trimbach 2012 Gewurztraminer (Alsace)                    France
# Heinz Eifel 2013 Shine Gewürztraminer (Rheinhes...      Germany
# Jean-Baptiste Adam 2012 Les Natures Pinot Gris ...       France
# Kirkland Signature 2011 Mountain Cuvée Cabernet...           US
# Leon Beyer 2012 Gewurztraminer (Alsace)                  France
# Louis M. Martini 2012 Cabernet Sauvignon (Alexa...           US
# ...

# %%
#Selecting better than average wines in Italy
wine_reviews.loc[wine_reviews.country == 'Italy'] #wines made in Italy

wine_reviews.loc[wine_reviews.points >= 90] #wines greated than average i.e.. >=90

#Thus
wine_reviews.loc[(wine_reviews.country == 'Italy') & (wine_reviews.points >= 90)]
# Out:
#        country                                        description  \
# 120      Italy  Slightly backward, particularly given the vint...
# 130      Italy  At the first it was quite muted and subdued, b...
# 133      Italy  Einaudi's wines have been improving lately, an...
# 135      Italy  The color is just beginning to show signs of b...
# 140      Italy  A big, fat, luscious wine with plenty of toast...
# 141      Italy  This is one of the more complex wines from the...
# 158      Italy  Baked plum, Asian spice, vanilla and menthol a...
# 159      Italy  Intense aromas of ripe red berry, menthol, esp...
# 200      Italy  Aromas of mature black-skinned berry, tobacco ...
# 201      Italy  Made with 60% Pinot Bianco, 30% Chardonnay and...
# 216      Italy  Black-skinned berry, pipe tobacco and Mediterr...
# 221      Italy  This opens with enticing aromas of chamomile f...
# 222      Italy  Chopped herb, forest floor, leather, espresso ...
# ...

# %%
#Pandas have few built-in conditional selectors.
#1. isin
#2. isnull

#isin - lets us select data whoes value is in a list of values
#isnull - lets us highlight values which are not empty (NaN)

# %%
#select eines only from Italy or France
wine_reviews.loc[wine_reviews.country.isin(['Italy','France'])]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 7       France  This dry and restrained wine offers spice in p...
# 9       France  This has great depth of flavor with its fresh ...
# 11      France  This is a dry wine, very spicy, with a tight, ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# 26       Italy  Pretty aromas of yellow flower and stone fruit...
# 27       Italy  Aromas recall ripe dark berry, toast and a whi...
# 28       Italy  Aromas suggest mature berry, scorched earth, a...
# 30      France  Red cherry fruit comes laced with light tannin...
# 31       Italy  Merlot and Nero d'Avola form the base for this...
# ...

# %%
#Filter out wines lacking a price tag 
wine_reviews.loc[wine_reviews.price.notnull()]
# Out:
#             country                                        description  \
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# 12               US  Slightly reduced, this wine offers a chalky, t...
# ...

# %%
#Assigning data to a dataframe

wine_reviews['critic'] = 'everyone' #constant value

wine_reviews['index_backwards'] = range(len(wine_reviews), 0, -1) #iterable values

# %%
wine_reviews.loc[wine_reviews.index.isin([0,1,10,100])].loc[:, ['country', 'province', 'region_1', 'region_2']]
# Out:
#       country           province      region_1      region_2
# 0       Italy  Sicily & Sardinia          Etna           NaN
# 1    Portugal              Douro           NaN           NaN
# 10         US         California   Napa Valley          Napa
# 100        US           New York  Finger Lakes  Finger Lakes

# %%
wine_reviews.loc[0:99, ['country', 'variety']]
# Out:
#       country                   variety
# 0       Italy               White Blend
# 1    Portugal            Portuguese Red
# 2          US                Pinot Gris
# 3          US                  Riesling
# 4          US                Pinot Noir
# 5       Spain        Tempranillo-Merlot
# 6       Italy                  Frappato
# 7      France            Gewürztraminer
# 8     Germany            Gewürztraminer
# 9      France                Pinot Gris
# 10         US        Cabernet Sauvignon
# 11     France            Gewürztraminer
# 12         US        Cabernet Sauvignon
# 13      Italy         Nerello Mascalese
# 14         US                Chardonnay
# 15    Germany                  Riesling
# 16  Argentina                    Malbec
# 17  Argentina                    Malbec
# 18      Spain         Tempranillo Blend
# 19         US                  Meritage
# 20         US                 Red Blend
# 21         US                Pinot Noir
# ...

# %%
df = wine_reviews
df.loc[(df.points>=95) & (df.country.isin(['Australia', 'New Zealand']))]
# Out:
#             country                                        description  \
# 345       Australia  This wine contains some material over 100 year...
# 346       Australia  This deep brown wine smells like a damp, mossy...
# 348       Australia  Deep mahogany. Dried fig and black tea on the ...
# 349       Australia  RunRig is always complex, and the 2012 doesn't...
# 356       Australia  Dusty, firm, powerful: just a few apt descript...
# 360       Australia  Bacon and tapenade elements merge easily on th...
# 365       Australia  The Taylor family selected Clare Valley for it...
# 14354     Australia  This wine's concentrated dark fruit shows in t...
# 16538     Australia  Rich, dense and intense, this is a big, muscul...
# 28573     Australia  Astralis has become one of Australia's top col...
# 34502     Australia  This prodigious wine showcases Barossa's abili...
# 34506     Australia  If Standish's Relic is the feminine side of Sh...
# ...

# %%
#Output of describe() is type dependant. Its output changes based on type.
wine_reviews.points.describe() #numerical type
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
wine_reviews.taster_name.describe()
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %%
#Mean of a column
wine_reviews.points.mean()
# Out:
# 88.44713820775404

# %%
#To see a list of unique values
wine_reviews.taster_name.unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
#To see list of unique values and how often they occur in the dataset
wine_reviews.taster_name.value_counts()
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %%
# Map - takes one set of data and maps them to another set of data.
#2 mapping functions often used - 
#   1. map() - this function expects a single value of the series and returns a transformed version of that value.
#              returns a new series with all transformed values by the function.
#   2. apply() - used when we want to transform the whole dataframe by calling a custom method on each row.
#              returns a new DF with all transformed values by the function.

#These both do not modify the original data they are called on.

# %%
# Example of map() - suppose we want to re-mean the scores of the wines to 0.
review_points_mean = wine_reviews.points.mean()
wine_reviews.points.map(lambda p : p - review_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
# 2        -1.447138
# 3        -1.447138
# 4        -1.447138
# 5        -1.447138
# 6        -1.447138
# 7        -1.447138
# 8        -1.447138
# 9        -1.447138
# 10       -1.447138
# 11       -1.447138
# 12       -1.447138
# 13       -1.447138
# 14       -1.447138
# 15       -1.447138
# 16       -1.447138
# 17       -1.447138
# 18       -1.447138
# 19       -1.447138
# 20       -1.447138
# 21       -1.447138
# 22       -1.447138
# 23       -1.447138
# 24       -1.447138
# 25       -1.447138
# 26       -1.447138
# 27       -1.447138
# 28       -1.447138
# 29       -2.447138
#             ...
# 129941    1.552862
# 129942    1.552862
# 129943    1.552862
# 129944    1.552862
# 129945    1.552862
# 129946    1.552862
# 129947    1.552862
# 129948    1.552862
# 129949    1.552862
# 129950    1.552862
# 129951    1.552862
# 129952    1.552862
# 129953    1.552862
# 129954    1.552862
# 129955    1.552862
# 129956    1.552862
# ...

# %%
#Example of apply()

def remean_points(row):
    row.points = row.points - review_points_mean
    return row

wine_reviews.apply(remean_points, axis='columns')
#Since the axis is 'columns', so we have passed row to the remean function
#Had the axis been 'index', we would have to pass column to the remean function
# Out:
#             country                                        description  \
# 0             Italy  Aromas include tropical fruit, broom, brimston...
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 3                US  Pineapple rind, lemon pith and orange blossom ...
# 4                US  Much like the regular bottling from 2012, this...
# 5             Spain  Blackberry and raspberry aromas show a typical...
# 6             Italy  Here's a bright, informal red that opens with ...
# 7            France  This dry and restrained wine offers spice in p...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 9            France  This has great depth of flavor with its fresh ...
# 10               US  Soft, supple plum envelopes an oaky structure ...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
#Faster way of remeaning points
review_points_mean = wine_reviews.points.mean()
wine_reviews.points - review_points_mean
# Out:
# 0        -1.447138
# 1        -1.447138
# 2        -1.447138
# 3        -1.447138
# 4        -1.447138
# 5        -1.447138
# 6        -1.447138
# 7        -1.447138
# 8        -1.447138
# 9        -1.447138
# 10       -1.447138
# 11       -1.447138
# 12       -1.447138
# 13       -1.447138
# 14       -1.447138
# 15       -1.447138
# 16       -1.447138
# 17       -1.447138
# 18       -1.447138
# 19       -1.447138
# 20       -1.447138
# 21       -1.447138
# 22       -1.447138
# 23       -1.447138
# 24       -1.447138
# 25       -1.447138
# 26       -1.447138
# 27       -1.447138
# 28       -1.447138
# 29       -2.447138
#             ...
# 129941    1.552862
# 129942    1.552862
# 129943    1.552862
# 129944    1.552862
# 129945    1.552862
# 129946    1.552862
# 129947    1.552862
# 129948    1.552862
# 129949    1.552862
# 129950    1.552862
# 129951    1.552862
# 129952    1.552862
# 129953    1.552862
# 129954    1.552862
# 129955    1.552862
# 129956    1.552862
# ...

# %%
#Combining 2 series. This operation is faster than map() or apply() but they are not as flexible as them.
wine_reviews.country + " - " + wine_reviews.region_1
# Out:
# 0                          Italy - Etna
# 1                                   NaN
# 2                US - Willamette Valley
# 3              US - Lake Michigan Shore
# 4                US - Willamette Valley
# 5                       Spain - Navarra
# 6                      Italy - Vittoria
# 7                       France - Alsace
# 8                                   NaN
# 9                       France - Alsace
# 10                     US - Napa Valley
# 11                      France - Alsace
# 12                US - Alexander Valley
# 13                         Italy - Etna
# 14                   US - Central Coast
# 15                                  NaN
# 16                 Argentina - Cafayate
# 17                  Argentina - Mendoza
# 18             Spain - Ribera del Duero
# 19                        US - Virginia
# 20                        US - Virginia
# 21                          US - Oregon
# 22                      Italy - Sicilia
# ...
